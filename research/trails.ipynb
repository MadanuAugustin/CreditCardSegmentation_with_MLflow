# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Some generated or real data
# X = np.array([...])
import pandas as pd

X = pd.read_csv('D:\\Desktop2\\desktop3\\Desktop2\\CreditCardClustering\\artifacts\\data_transformation\\transformed_data_df.csv')

inertias = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertias)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette_scores = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    score = silhouette_score(X, kmeans.labels_)
    silhouette_scores.append(score)

plt.plot(range(2, 11), silhouette_scores)
plt.title('The Silhouette Method')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'Name' : ['apple', 'mango', 'grapes', 'strawberries']})

# %%
df.head()
# Out:
#            Name
# 0         apple
# 1         mango
# 2        grapes
# 3  strawberries

# %%
mylist = [2]

# %%
cluster_mapping = {0: 'cluster_A', 1: 'cluster_B', 2: 'cluster_C', 3: 'cluster_D'}

# %%
mapped_predictions = [cluster_mapping[pred] for pred in mylist]

# %%
mapped_predictions
# Out:
# ['cluster_C']
